# %% [markdown]
# # 載入所需套件

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from concurrent import futures
from tqdm import tqdm
from datetime import datetime
import re

# %% [markdown]
# # 定義進入每篇文章爬取推文資訊函數

# %%
def details_crawler(link_list):
    link=link_list[0]
    i=link_list[1]
    r=requests.get(link)
    s=BeautifulSoup(r.text,'html.parser')
    
    #文章內文
    content=s.select('#main-content')[0]
    if  '-----' in content.text:
        temp_info=content.text.split('-----')[0]
    else:
        temp_info=content.text.split('--')[0]
    info='\n'.join(temp_info.split('\n')[1:])
    
    #暱稱和日期
    temp=content.select('.article-meta-value')
    
    if temp==[]:
        date=np.nan
        name=np.nan
    else:
        date=datetime.strptime(temp[3].text,'%a %b %d %H:%M:%S %Y')
        temp_name=re.findall(r'\((\w+)\)',temp[0].text)
        if temp_name==[]:
            name=np.nan
        else:
            name=temp_name[0]
        
    #推文和分數
    comment=[]
    total_score=0
    
    try:
        for e in content.select('.push'):
            push_tag=e.select('.hl.push-tag')[0].text.replace(' ','')
            push_user=e.select('.f3.hl.push-userid')[0].text
            push_content=e.select('.f3.push-content')[0].text.strip(': ')
            push_time=e.select('.push-ipdatetime')[0].text.strip('\n').strip(' ')

            if '推' in push_tag:
                score=1
            elif '噓' in push_tag:
                score=-1
            else:
                score=0

            total_score+=score

            comment.append({'帳號':push_user,
                            '內容':push_content,
                            '心情':push_tag,
                            '分數':score,
                            '時間':push_time})
    except:
        pass
        
    return i,info,name,date,comment,total_score

# %% [markdown]
# # 定義爬取單頁Womentalk板文章資訊函數

# %%
def ptt_womentalk_crawler(url):   
    response=requests.get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    entrys=soup.select('div.r-ent')
    
    titles,ids,recommends,links=[],[],[],[]

    for entry in entrys:
        if entry.select('div.author')[0].text=='-':
            continue
        else:
            titles.append(entry.select('div.title a')[0].text)
            links.append('https://www.ptt.cc'+entry.select('div.title a')[0]['href'])
            ids.append(entry.select('div.author')[0].text)
            recommends.append(entry.select('div.nrec')[0].text)
    
    link_list=[]
    for i in range(len(links)):
        link_list.append([links[i],i])
    
    infos=[0]*len(links)
    names=[0]*len(links)
    dates=[0]*len(links)
    comments=[0]*len(links)
    total_scores=[0]*len(links)
    
    #進入每個連結爬取(執行thread層級的非同步任務)
    with futures.ThreadPoolExecutor(max_workers=8) as executor:
        results=list(executor.map(details_crawler,link_list))

        for future in results:
            i,info,name,date,comment,total_score=future
            infos[i]=info
            names[i]=name
            dates[i]=date
            comments[i]=comment
            total_scores[i]=total_score
    
    df=pd.DataFrame({
        '標題':titles,
        '時間':dates,
        '帳號':ids,
        '暱稱':names,
        '推數':recommends,
        '分數':total_scores,
        '內容':infos,
        '推文':comments,
        '網址':links
    })
    
    return df

# %% [markdown]
# # 定義爬取多頁Womentalk板文章資訊函數

# %%
def page_condition_function(page):    
    url='https://www.ptt.cc/bbs/WomenTalk/index.html'    
    dfs=[]
   
    for i in tqdm(range(page)):    
        d=ptt_womentalk_crawler(url)
        dfs.append(d)
        response=requests.get(url)
        soup=BeautifulSoup(response.text,'html.parser')
        paging=soup.select('div.btn-group-paging a')
        url='https://www.ptt.cc'+paging[1]['href']
    
    df=pd.concat(dfs,ignore_index=True)
    
    return df

# %% [markdown]
# # 抓取指定總頁數Womentalk板文章資訊

# %%
df=page_condition_function(10)
df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00
# 3                NaN   4    3
# 4         DANISELIU_   3    3
# 5              PTT金庸   爆  125
# 6                NaN        0
# 7        我想吃雲之上夢見的腳皮   2    5
# 8                 味丹   8   18
# 9                西門啦   1    1
# 10           磨刀霍霍向肥羊   8    8
# 11            master   3    3
# 12                烏烏   5    5
# 13             住在月球上  12   12
# 14               NaN  30   31
# 15         mermaidya   5    5
# 16              芭樂本人   3    3
# 17     best_troll_tw   1    1
# 18               三三三   6    6
# 19             我愛復古風   9    9
# 20           idfcwys        0
# 21               NaN  11   11
# 22           東七七玩批踢踢   7    7
# 23               小芙尼   9    9
# 24                胖呆   5    5
# 25           在天橋下的天使   2    2
# 26                蛆蛆  22   24
# 27               NaN   4    4
# 28               NaN   1    1
# 29             楚留香雞排   8    8
# ..               ...  ..  ...
# 151               胖呆        0
# 152             咬我阿豬   1    1
# 153              NaN       -6
# 154          在天橋下的天使   8    8
# 155        Faithless   6    6
# 156            三民李連杰   4    4
# 157      okokokiknow   7    7
# 158               曉玫        0
# 159             路人水水   2    2
# 160             害怕愛雪       -1
# 161           master   4    4
# 162          IXLiang   4    4
# 163              NaN  27   27
# 164            楚留香雞排   5    5
# 165              335       -2
# 166              NaN   4    4
# 167              NaN   8    8
# 168              NaN   4    4
# 169               中二   3    3
# 170             姆姆波波   9    9
# 171               中二        0
# 172              NaN   2    2
# 173              NaN   3    3
# 174  niflheim一律打趴武力放   2    2
# 175          磨刀霍霍向肥羊   5    5
# 176            愛上速霸路        0
# 177          絢麗舞廳小公主        0
# 178              335   2    2
# 179                飯  27   27
# 180              NaN  21   21
#
#                                                     內容  \
# 0    去年是買外面一組那種套裝式的烤肉箱\n覺得偏貴東西不多新鮮度也還好\n今年拒絕同事的烤肉聚\...
# 1    每次看到有人發問殺蟑螂的文章\n底下留言都會提到一點絕\n\n但我現在比較困擾的是…螞蟻!!...
# 2    我看女生穿個短裙或是絲襪 還是透一點的 回頭率就很高 就能很簡單獲得\n很多男生關心 容易吸...
# 3    其中一個表姊最近生了\n\n是個頭好壯壯的兒子\n\n看她發限時動態說一家很幸福\n\n也為...
# 4    今年得知得延畢一整學年了\n原本只是延畢一學期的\n怪我選課沒有注意好到底缺了什麼課\n選了...
# 5    九月到了\n\n暑假過了\n\n開學了\n\n閒聊區可以閒聊喔~~\n\n但基本的PTT禮儀...
# 6    ║                            ║\n              ...
# 7    大家晚安\n\n\n板規13. 文章、推文不得出現資金事宜、贈送禮物或任何徵人相關訊息。\n...
# 8    [總覽]\n\n\n           一、徵選及就任資格\n\n           二...
# 9    ※ 引述《eric112 (eric)》之銘言：\n: iPhone第一支有2G Ram的手...
# 10   他舉止比較女性化\n外表白皙清秀\n然後很會裝可愛，撒嬌\n很會自拍\n都混在女生堆中\n給...
# 11   剛剛肥肥去溫州大餛飩吃麵\n\n點了鮮蝦抄手麵\n\n然後等了很久還沒來，肥肥就看他們\n\...
# 12   \n乳堤\n最近跟朋友聊天講到這件事情\n他說他爸媽是在大學宿營認識的\n然後一路交往結婚生...
# 13   穿低怎麼了\n以前穿低一點(也沒多低，就是彎腰微露溝那種)\n就會被長輩念\n\n明明又沒有...
# 14   如題\n\n現在iPhone已經出到11\n\n快要推出12了\n\n那還有人在用iPhon...
# 15   大家午安，如題，想請教大家一個問題QQ\n事情是發生在我妹身上，她前幾天求職遇到詐騙，\n對...
# 16   \n以前當學生的時候都是到屈臣氏買ＤＨＣ的鐵、維他命Ｃ跟Ｂ群之類的\n\n沒ＤＨＣ就買活沛多...
# 17   \n如題\n\n最近有感於人生無常，去研究了一下保險\n\n大概知道人生在世，跟個人健康、安...
# 18   雖然她的年紀對我來說是姐啦\n\n感覺她就是想到哪裡玩就去哪裡玩\n缺錢了就開個直播就有好多...
# 19   今天中午請要去買午餐的同事幫買水\n結果問我是要一般的瓶裝水還是礦泉水?\n我一頭霧水，不就...
# 20   之前去過一次覺得很不錯\n結果後來就遇到很雷的....\n因為兩次的體驗落差太大 整個很擔心...
# 21   \n因為公司主管最近不知道吃了什麼藥，請了講師來幫部門內的大家上課。\n\n男生們好像都聽得...
# 22   \n一直都被ig限時動態廣告打擾的很煩\n\n有尤其最近發現每看兩則，就會有一則廣告\n\n...
# 23   嗨嗨大家午安~我是開學忙碌的芙尼~\n\n這學期接了社團幹部、必修課又有點難度，\n然後再加...
# 24   是這樣子的啦\n\n這陣子剛開學\n每次上課都看到身邊同堂課的同學手邊都多了一台iPad\n...
# 25   \n主管和同事都不在辦公室裡\n\n那我要幹嘛\n\n1.乖乖做無聊的掃描工作邊用耳機聽Po...
# 26   \n我和男友是在網路上認識的，是遠距離\n我22，他24。認識四個月，交往四個月\n\n一開...
# 27   看到大家熱烈的在聊iPhone\n\n之前換iPhone11 Pro Max 512g\n\...
# 28   ※ 引述《flower42 (栗悟飯與龜波功)》之銘言：\n: 剛剛看隔壁版的文章\n: 才...
# 29   如題\n\n本人喜歡吃肉肉  然後補充蛋白質\n\n有啥套餐推薦嗎  還是什麼哪一款的乳酪堡...
# ..                                                 ...
# 151  是這樣子的啦\n\n睡覺醒來突然發現已經開機了\n太爽了吧\n看來我的樂趣又回來了\n\n只...
# 152  明明有那麼多想推的文章\n\n那知道不論怎麼按下送出\n\n文章都推不出去\n\n這樣的痛苦...
# 153  如題\n\nPTT提早開機\n\n因該還有很多人不知道這件事\n\n乖乖地待在外面等\n\n...
# 154  \n\n老實說我現在心情蠻五味雜陳的\n\n剛剛在主管留言的通訊軟體叫我前去HR那裡領取離職...
# 155  \n小弟我跟女朋友還有一位女性好朋友要開車去花蓮玩啦！\n\n我們剛剛一路上的歌單是有主題的...
# 156  不知道大家有沒有發現\n\n現在的年輕女生當中流行一種新穿法\n\n就是下半身穿非常短緊小的...
# 157  \n各位氣質女孩們好\n\n最近跟朋友談心的時候，被問到有沒有 IG\n\n我說我沒有IG，...
# 158  一連兩三天在路上被路人狂踩到腳後跟\n而且都是踩右腳嗚嗚\n雖然知道不是故意的\n但還是會有...
# 159  水水我啦\n\n平常讀書一章要讀兩天\n\n今天居然兩小時讀兩章\n\n嚇了我好大一跳！？\...
# 160  難過\n\n上半天好不容易熬過去了，結果現在不能推噓文，不能推噓文的ptt，沒資格稱為ptt...
# 161  看你要聽真實的還是假的理由\n\n\n真實理由-\n被拍其實會興奮，很多人喜歡被拍\n\n假...
# 162  如題，想買花送心儀的人：)\n\n研究花語時，本來想買香檳玫瑰或是深紅色薔薇，但怕很快就凋謝...
# 163  以前也都隨便買隨便拿\n\n夜市 某藍小舖 披居 net 買一堆\n阿姨送的可能是他女兒不背...
# 164  如題\n\n\n感覺好冷淡qq  是因為星期天大家都出去玩嗎\n\n\n還是真的ptt本身就...
# 165  看了調查報告 不只台南學甲\n\n一堆公司都是直接埋土裡 再租給農民耕種\n\n所以附近水質...
# 166  這一陣子一直聞到燒香的味道\n\n但是家人都沒有\n\n有時候在公車上帶著口罩\n\n或者是...
# 167  21年前的9月21號凌晨1點47分\n\n發生這個讓台灣人難以遺忘的地震\n\n大部分的人通...
# 168  最近開始參加了一些婚禮\n\n幾乎每個人都會拿個喜糖沾個喜氣\n\n不過有些喜糖感覺是婚宴會...
# 169  日子過得不好\n主管一直把壓力丟給我\n親戚往生\n烏龜生病\n朋友吵架\n\n\n接下來怎...
# 170  大三的時候我加入一個社團\n但我是下學期才中途加入，跟裡面的人比較不熟\n只是隨著後續辦活動...
# 171  是什麼感覺\n\n很久沒有過了\n每天都在趕趕趕\n互相不耐煩 不講話\n哀\n\n\n很久...
# 172  嗨嗨\n\n各位女板姊姊妹妹們大家好阿\n\n是降的拉\n\n本肥想問問阿\n\n如果能有那...
# 173  嗨嗨\n\n各位女板姊姊妹妹們大家好阿\n\n是降的拉\n\n本肥想分享一下愛戀的心情拉\n...
# 174  ※ [本文轉錄自 Boy-Girl 看板 #1VPuaXk8 ]\n\n作者: voncro...
# 175  發現好像比較少好看的韓劇了\n相反地，\n很多人跑去看陸劇\n反而陸劇比較有討論度的感覺\n...
# 176  ※ 引述《wwwson1256 (太陽花青年)》之銘言：\n: 有些女生喜歡拿名牌包穿名牌衣...
# 177  在南京譯林有出一套雨果全集\n\n有一本收錄三篇短篇\n\n第一篇 布格雅加爾\n\n第二篇...
# 178  平常吃的肉量:豬肉>>>雞羊>>>牛\n\n羊肉雖好吃但太貴 只有去吃到飽才會猛吃\n\n原...
# 179  \n我本人是平時不會化妝，但有時候出去玩或是假日無聊在家才會化，對我而言化妝是一件隨心情擺動...
# 180  事情是這樣的\n\n原訂今天就和男友說好要一起去野餐\n\n奈何今天天氣狀況不好早上下雨\n...
#
#                                                     推文  \
# 0    [{'帳號': 'eva19452002', '內容': '一年才一次中秋節，在那邊精打細算...
# 1    [{'帳號': 'eva19452002', '內容': '搬家', '心情': '→', ...
# 2    [{'帳號': 'chocopoodle', '內容': 'https://i.imgur....
# 3    [{'帳號': 'shao9850', '內容': '每次照鏡子的時候', '心情': '推...
# 4    [{'帳號': 'minifat', '內容': '這文都不知道怎回 很多都在搞公司了問剛上...
# 5    [{'帳號': 'hua828797', '內容': '錢', '心情': '推', '分數...
# 6                                                   []
# 7    [{'帳號': 'kuijun228', '內容': '那送p幣怎辦 完了', '心情': ...
# 8    [{'帳號': 'YYC042', '內容': '我選 大家投我嗎？', '心情': '推'...
# 9    [{'帳號': 'meishan31', '內容': '電池變大30%那空間夠嗎?', '心...
# 10   [{'帳號': 'foodie561', '內容': '就算不是可能也是transgende...
# 11   [{'帳號': 'FlynnZhang', '內容': '一樓爌肉', '心情': '→',...
# 12   [{'帳號': 'sahazi', '內容': '阿公阿嬤帶大 完。', '心情': '→'...
# 13   [{'帳號': 'chungrew', '內容': '支持妳做自己', '心情': '推',...
# 14   [{'帳號': 'kuijun228', '內容': '我手上還有4s只是沒有WiFi 要哭...
# 15   [{'帳號': 'blackrain', '內容': '開小孩帳戶呢', '心情': '推'...
# 16   [{'帳號': 'claymath', '內容': 'DHC b/c ，萊萃美的葉黃素跟花青...
# 17   [{'帳號': 'LiveInNow', '內容': 'https://youtu.be/W...
# 18   [{'帳號': 'kimura0701', '內容': '我也好羨慕', '心情': '→'...
# 19   [{'帳號': 'yorkyoung', '內容': '礦物質吧？', '心情': '推',...
# 20   [{'帳號': 'pttdouble', '內容': '我怎麼覺得你在講柯文哲...', '...
# 21   [{'帳號': 'alohac', '內容': '我也覺得Python真的好難嗚嗚嗚...'...
# 22   [{'帳號': 'Tapqou', '內容': '客家', '心情': '推', '分數':...
# 23   [{'帳號': 'ffooxx', '內容': 'https://i.imgur.com/h...
# 24   [{'帳號': 'sodahaini', '內容': '還有人用愛奇藝？', '心情': '...
# 25   [{'帳號': 'Iakane', '內容': '自拍', '心情': '推', '分數':...
# 26   [{'帳號': 'vdml', '內容': '年輕就是這樣 慢慢成長吧', '心情': '推...
# 27   [{'帳號': 'guessclaire', '內容': '我換了i11 128g 照片跟影...
# 28   [{'帳號': 'twmarstw7758', '內容': '羨慕', '心情': '推',...
# 29   [{'帳號': 'shanshanman', '內容': '白醬培根義大利麵', '心情':...
# ..                                                 ...
# 151                                                 []
# 152  [{'帳號': 'Zhang97226', '內容': '對啊', '心情': '推', '...
# 153  [{'帳號': 'zzhhanhan', '內容': '我來了', '心情': '噓', '...
# 154  [{'帳號': 'beams156', '內容': '拍拍QQ', '心情': '推', '...
# 155  [{'帳號': 'a30649574', '內容': '風箏、夢想藍圖', '心情': '推...
# 156  [{'帳號': 'yvonne13', '內容': '疑問 為什麼路上那麼多男生穿荷葉邊有油...
# 157  [{'帳號': 'jjaek', '內容': '平常用臉書比較多', '心情': '推', ...
# 158                                                 []
# 159  [{'帳號': 'O300', '內容': '♡♡♡', '心情': '→', '分數': ...
# 160  [{'帳號': 'ggghhi', '內容': '哭哭', '心情': '推', '分數':...
# 161  [{'帳號': 'pauljet', '內容': '跟你講啦 大多數人愛情到某個程度都想追求...
# 162  [{'帳號': 'kbt2720', '內容': '芒果、雞蛋花都不錯，喜歡大太陽又不容易曬...
# 163  [{'帳號': 'anguslf2', '內容': 'LV monogram 吧', '心情...
# 164  [{'帳號': 'O300', '內容': '去DCARD了啊', '心情': '→', '...
# 165  [{'帳號': 'FlynnZhang', '內容': '八卦是你看中天', '心情': '...
# 166  [{'帳號': 'dan5120', '內容': '鼻子壞掉了', '心情': '→', '...
# 167  [{'帳號': 'TerranLiu', '內容': '剛吃完宵夜準備睡覺。', '心情':...
# 168  [{'帳號': 'guessclaire', '內容': '喜歡軟糖那種', '心情': '...
# 169  [{'帳號': 'trylin', '內容': '不能離職就忍', '心情': '推', '...
# 170  [{'帳號': 'littlelaw', '內容': '不要對別人期望太高', '心情': ...
# 171                                                 []
# 172  [{'帳號': 'dan5120', '內容': '誰的 王心凌嗎', '心情': '→',...
# 173  [{'帳號': 'guessclaire', '內容': '你梗到底都怎麼想的', '心情'...
# 174  [{'帳號': 'RaiGend0519', '內容': '到頭來還是沒什麼有效的反制手段'...
# 175  [{'帳號': 'kbt2720', '內容': '你有看再見鬼媽媽嗎', '心情': '→...
# 176  [{'帳號': 'MooonRiver', '內容': '最後兩句真有道理XD', '心情'...
# 177  [{'帳號': 'evilaffair', '內容': '雨果李洛克達爾', '心情': '...
# 178  [{'帳號': 'panda80911', '內容': '豬>=雞>>>>>羊>=牛吧', ...
# 179  [{'帳號': 'newsnew', '內容': '當然是當男友的洋娃娃 你的想法重要嗎',...
# 180  [{'帳號': 'imij', '內容': '他以後真的不會找你朋友家的聚會了。', '心情...
#
#                                                     網址
# 0    https://www.ptt.cc/bbs/WomenTalk/M.1600759073....
# 1    https://www.ptt.cc/bbs/WomenTalk/M.1600759170....
# 2    https://www.ptt.cc/bbs/WomenTalk/M.1600759629....
# 3    https://www.ptt.cc/bbs/WomenTalk/M.1600760357....
# 4    https://www.ptt.cc/bbs/WomenTalk/M.1600760416....
# 5    https://www.ptt.cc/bbs/WomenTalk/M.1598891489....
# 6    https://www.ptt.cc/bbs/WomenTalk/M.1599127903....
# 7    https://www.ptt.cc/bbs/WomenTalk/M.1600099556....
# 8    https://www.ptt.cc/bbs/WomenTalk/M.1600180533....
# 9    https://www.ptt.cc/bbs/WomenTalk/M.1600749765....
# 10   https://www.ptt.cc/bbs/WomenTalk/M.1600749952....
# 11   https://www.ptt.cc/bbs/WomenTalk/M.1600751255....
# 12   https://www.ptt.cc/bbs/WomenTalk/M.1600751348....
# 13   https://www.ptt.cc/bbs/WomenTalk/M.1600751861....
# 14   https://www.ptt.cc/bbs/WomenTalk/M.1600752362....
# 15   https://www.ptt.cc/bbs/WomenTalk/M.1600752843....
# 16   https://www.ptt.cc/bbs/WomenTalk/M.1600753091....
# 17   https://www.ptt.cc/bbs/WomenTalk/M.1600753622....
# 18   https://www.ptt.cc/bbs/WomenTalk/M.1600753858....
