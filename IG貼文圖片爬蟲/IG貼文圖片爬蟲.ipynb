# %% [markdown]
# # 載入所需套件

# %%
import requests
from bs4 import BeautifulSoup
import json
from urllib.request import urlretrieve
import re
from tqdm import tqdm
import numpy as np
import pandas as pd
import time
from datetime import datetime
import os

# %% [markdown]
# # 定義爬取IG帳號基本資訊函數

# %%
def ig_summary_crawler(id_name):
    header={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'}
    url='https://www.instagram.com/{}/'.format(id_name)
    response=requests.get(url,headers=header)
    soup=BeautifulSoup(response.text,'lxml')
    json_part=soup.find_all('script',type='text/javascript')[3].string
    json_part=json_part[json_part.find('=')+2:-1]
    data=json.loads(json_part)
    user_data=data['entry_data']['ProfilePage'][0]['graphql']['user']

    user_id=user_data['id']
    full_name=user_data['full_name']
    biography=user_data['biography']
    followed_num=user_data['edge_followed_by']['count']
    follow_num=user_data['edge_follow']['count']
    entry_num=user_data['edge_owner_to_timeline_media']['count']

    summary_df=pd.DataFrame({
        '編號':user_id,
        '名稱':full_name,
        '簡介':biography,
        '被追蹤數':followed_num,
        '追蹤數':follow_num,
        '貼文數':entry_num
    },index=[0])
    
    directory='IG圖片爬蟲/{}'.format(id_name)
    if not os.path.isdir(directory):
        os.makedirs(directory)
    
    summary_df.to_csv('{}/{}個人簡介.csv'.format(directory,id_name),encoding='utf_8_sig',index=False)
    
    return summary_df,entry_num,user_id

# %% [markdown]
# # 定義爬取IG帳號貼文、圖片函數

# %%
def user_data_crawler(url):
    header={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'}
    response=requests.get(url,headers=header)
    
    try:
        soup=BeautifulSoup(response.text,'lxml')
        json_part=soup.find_all('script',type='text/javascript')[3].string
        json_part=json_part[json_part.find('=')+2:-1]
        data=json.loads(json_part)
        user_data=data['entry_data']['ProfilePage'][0]['graphql']['user']
    except:
        #處理第2頁以後user_data的json格式不同
        user_data=json.loads(response.text)['data']['user']
    
    return user_data

# %%
def ig_img_page_crawler(user_data):
    one_page_info=user_data['edge_owner_to_timeline_media']['edges']

    texts=[]
    tags=[]
    ats=[]
    img_links=[]
    post_links=[]
    tag_nums=[]
    at_nums=[]
    img_nums=[]
    message_nums=[]
    heart_nums=[]
    ids=[]
    post_times=[]
    locations=[]

    #每個one_page_info首頁最多有12篇，第2頁以後每頁最多有50篇
    for i in range(len(one_page_info)):
        img_link=[]
        try:
            text=one_page_info[i]['node']['edge_media_to_caption']['edges'][0]['node']['text']
            texts.append(text)
            #抓取ig貼文#
            if '#' in text:
                tag_list=re.findall(r'#([^ |\n]+)',text)
                tag_nums.append(len(tag_list))
                tags.append('\n'.join(tag_list))
            else:
                tag_nums.append(0)
                tags.append('')
            #抓取ig貼文@
            if '@' in text:
                at_list=re.findall(r'@([^ |\n]+)',text)
                at_nums.append(len(at_list))
                ats.append('\n'.join(at_list))
            else:
                at_nums.append(0)
                ats.append('')
        except:
            #處理ig貼文沒文字敘述情況
            texts.append('')
            tag_nums.append(0)
            tags.append('')
            at_nums.append(0)
            ats.append('')
        try:
            #處理ig貼文可能不只1張圖片情況
            img_info=one_page_info[i]['node']['edge_sidecar_to_children']['edges']
            img_num=len(img_info)
            img_nums.append(img_num)
            
            for j in range(img_num):
                img_link.append(img_info[j]['node']['display_url'])
            img_links.append(img_link)
        except:
            img_nums.append(1)
            img_links.append(one_page_info[i]['node']['display_url'])
        try:
            locations.append(one_page_info[i]['node']['location']['name'])
        except:
            #處理ig貼文沒打卡地點情況
            locations.append('')
        
        message_nums.append(one_page_info[i]['node']['edge_media_to_comment']['count'])
        heart_nums.append(one_page_info[i]['node']['edge_media_preview_like']['count'])
        ids.append(one_page_info[i]['node']['id'])
        int_time=one_page_info[i]['node']['taken_at_timestamp']
        post_times.append(datetime.fromtimestamp(int_time).strftime('%Y-%m-%d %H:%M:%S'))
        post_code=one_page_info[i]['node']['shortcode']
        post_links.append('https://www.instagram.com/p/{}/'.format(post_code))
        
    img_df=pd.DataFrame({
        '編號':ids,
        '時間':post_times,
        '貼文':texts,
        '標籤':tags,
        '標註':ats,
        '打卡地點':locations,
        '留言數':message_nums,
        '愛心數':heart_nums,
        '標籤數':tag_nums,
        '標註數':at_nums,
        '圖片數':img_nums,
        '貼文網址':post_links,
        '圖片網址':img_links 
    })        

    return img_df

# %%
def ig_img_total_crawler(entry_num,user_id,id_name):
    img_dfs=[]
    url='https://www.instagram.com/{}/'.format(id_name)
    user_data=user_data_crawler(url)
    img_df=ig_img_page_crawler(user_data)
    img_dfs.append(img_df)
    next_code=user_data['edge_owner_to_timeline_media']['page_info']['end_cursor']
    
    #首頁最多有12篇，第2頁以後每頁最多50篇
    if (entry_num-12)%50==0:
        iter_times=int((entry_num-12)/50)
    else:
        iter_times=int((entry_num-12)/50)+1
    
    for i in tqdm(range(iter_times)):
        url='https://www.instagram.com/graphql/query/?query_hash=f2405b236d85e8296cf30347c9f08c2a&variables=%7B%22id%22%3A%22{}%22%2C%22first%22%3A50%2C%22after%22%3A%22{}%3D%3D"%7D'.format(user_id,next_code.replace('=',''))
        time.sleep(0.5)
        user_data=user_data_crawler(url)
        img_df=ig_img_page_crawler(user_data)
        img_dfs.append(img_df)
        next_code=user_data['edge_owner_to_timeline_media']['page_info']['end_cursor']
    
    total_img_df=pd.concat(img_dfs,ignore_index=True)
    
    directory='IG圖片爬蟲/{}'.format(id_name)
    if not os.path.isdir(directory):
        os.makedirs(directory)
    
    total_img_df.to_csv('{}/{}貼文資訊.csv'.format(directory,id_name),encoding='utf_8_sig',index=False)
    
    return total_img_df

# %% [markdown]
# # 定義下載儲存IG帳號圖片、貼文檔案函數

# %%
def download_img_text(id_name,total_img_df):
    for i in tqdm(range(len(total_img_df))):
        directory='IG圖片爬蟲/{}/{}'.format(id_name,i)
        if not os.path.isdir(directory):
            os.makedirs(directory)
        
        text=total_img_df.loc[i,'貼文']
        tag=total_img_df.loc[i,'標籤']
        at=total_img_df.loc[i,'標註']
        img_links=total_img_df.loc[i,'圖片網址']
        
        with open('{}/貼文.txt'.format(directory),'w',encoding='utf-8') as f:
            f.write(text) 
        
        with open('{}/標籤.txt'.format(directory),'w',encoding='utf-8') as f:
            f.write(tag) 
            
        with open('{}/標註.txt'.format(directory),'w',encoding='utf-8') as f:
            f.write(at) 
        
        try:
            for j in range(len(img_links)):
                urlretrieve(img_links[j],'{}/{}.png'.format(directory,j))
        except:
            urlretrieve(img_links,'{}/{}.png'.format(directory,0))

# %% [markdown]
# # 特定IG公開帳號爬蟲

# %%
id_name=input('請輸入IG帳號 : ')
try:
    summary_df,entry_num,user_id=ig_summary_crawler(id_name)
    print('輸入的IG帳號為：{}，共有{}篇貼文'.format(id_name,entry_num))
except:
    print('此帳號輸入錯誤(或設定不公開)')
try:
    total_img_df=ig_img_total_crawler(entry_num,user_id,id_name)
    print('圖片貼文表格下載成功')
except:
    print('圖片貼文表格下載失敗')
try:
    download_img_text(id_name,total_img_df)
    print('圖片貼文檔案下載成功')
except:
    print('圖片貼文檔案下載失敗')
# Out:
# 請輸入IG帳號 : ekey
# 輸入的IG帳號為：ekey，共有781篇貼文
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:40<00:00,  1.83s/it]
# 圖片貼文表格下載成功
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 781/781 [27:57<00:00,  2.23it/s]
# 圖片貼文檔案下載成功

# %%
total_img_df
# Out:
#                       編號                   時間  \
# 0    2392287252653778449  2020-09-06 22:34:45
# 1    2390745088761265265  2020-09-04 19:30:45
# 2    2388721584679167177  2020-09-02 00:30:24
# 3    2387887545114340195  2020-08-31 20:53:19
# 4    2387260346233282811  2020-08-31 00:07:11
# 5    2386344290115505392  2020-08-29 17:47:09
# 6    2385764711466519415  2020-08-28 22:35:38
# 7    2384762614989988141  2020-08-27 13:24:38
# 8    2383393334478427720  2020-08-25 16:04:07
# 9    2381834023935454277  2020-08-23 12:26:03
# 10   2380542770925205405  2020-08-21 17:40:34
# 11   2376941688764418241  2020-08-16 18:25:51
# 12   2369748798158038054  2020-08-06 20:14:52
# 13   2366781764285713950  2020-08-02 17:59:54
# 14   2363882844391983299  2020-07-29 18:00:16
# 15   2360322595449916705  2020-07-24 20:06:41
# 16   2358873473257700384  2020-07-22 20:07:32
# 17   2357410554011611152  2020-07-20 19:40:59
# 18   2356725112379512674  2020-07-19 20:59:08
# 19   2356105624567065372  2020-07-19 00:28:19
# 20   2355338331075444647  2020-07-17 23:03:50
# 21   2355257480136497940  2020-07-17 20:23:12
# 22   2354497318496776958  2020-07-16 19:12:54
# 23   2353884627797462577  2020-07-15 22:55:35
# 24   2353067865459737930  2020-07-14 19:52:50
# 25   2352298028433169674  2020-07-13 18:23:18
# 26   2351703936561063923  2020-07-12 22:42:57
# 27   2350177525467741044  2020-07-10 20:10:14
# 28   2347866799147572501  2020-07-07 15:39:14
# 29   2343633129674942469  2020-07-01 19:27:42
# ..                   ...                  ...
# 751  1083719862385388050  2015-09-28 11:04:56
# 11   每朝\n每朝双纖\n每朝健康\n喝茶解膩\n去油解膩\n油膩美食最佳搭配\n要乖乖喝喔\np...
# 12                           生活就像一場運動#喝水不夠喝FIN就好#黑松FIN
# 13           像極了愛情\n除斑緊緻雷射\n抽獎\n破3萬\n謝謝你悶\n千代圈圈\n東方八千代
# 14
# 15
# 16               依學小教室\n冷光美白\n牙齒美白\n夏天哪裡都想美白\n頭髮長度也差太多
# 17                              清水斷崖\n牛奶湖\n花蓮景點\n花蓮小旅行
# 18            好野人\n花蓮清水斷崖\n花蓮清水斷崖sup\n花蓮大海洋\n清水斷崖\n卜派團
# 19   好野人\n私密處除毛\n花蓮清水斷崖\n花蓮清水斷崖sup\n花蓮sup\n花蓮海上活動\n...
# 20   SubwayTaiwan\n美味時刻任我享樂\nfeelgoodtastegood\nSum...
# 21
# 22                                        霧雕眉\n霧眉\n素顏眉
# 23                                        Rockit\n樂淇蘋果
# 24         小亀有かき冰\n宜蘭冰店\n宜蘭美食\n宜蘭景點\n小龜冰店\n小龜有かき冰\n小龜有
# 25   花蓮貨櫃星巴客\n犀牛盾手機殼\n犀牛盾\n客製化手機殼\niphone殼\niphone手...
# 26                          健身工廠石牌廠\n健身\n健身女孩\nworkout
# 27   玩具總動員\ntoystory\n娃娃控\n迪士尼\n皮克斯#迪士尼娃娃\n內湖costco...
# 28
# 29                                                 霧雕眉
# ..                                                 ...
# 751  bigbang\nmade\nGD\nTOP\nseungri\ntaeyang\nDJ\n...
# 752
# 753               upset\ndissapointed\nsadness\n憂憂\n厭厭
# 754               byesunday\ndontbelate\nfocus\nselfie
# 755                                    綠蓋茶\ntaipeitour
# 756  8%\nicecream\nhotday\nsummer\ngirls\nshopping\...
# 757  杯緣子\nフチ子\nfuchiko\ntokyospecial\n東京限定\npanda\n...
# 758           杯緣子\nフチ子\nfuchiko\ntoyholic\n進擊的巨人#喝醉的巨人
# 759                                  杯緣子\nフチ子\nfuchiko
# 760     minionlover\nminion\nFriday\nfighting\ndreamer
# 761  minion\nminionlover\npopcorncan#universal\next...
# 762                korea\ngyongbokkung\npalace\nhanbok
# 763                                      德記洋行\nTAITTEA
# 764                       武士鞋\nairhuarache\nblackwhite
# 765    watermelontoast\nmatchaflavor\nstrawberryflavor
# 766                                 弗列斯\nFresh\nGolden
# 767                            愛搗亂\nminion\nselfie\n38
# 768     minion\nMcdonalds\ndancing\nlikepenguin\nwaver
# 769                    GATAO\nwegames\nmobilegame\n祝大賣
# 770  minion\naottergirls\notter窩\nvideo\nM\ncelebra...
# 771  my\ndoubleexposure\nmultipleexposure\nselfie\n...
# 772  cony\nlinecharacter\npapertape\nstationery\nco...
# 773    sunset\nVirgo\neverythingalright\nsky\ninstasky
# 774               tropicalfish\nsnorkeling\ngettingtan
# 775                                   BaliKuta\nSunset
# 776                           mee'scafe\nthanktobroRay
# 777                                  sister\nM\nbrunch
# 778                                             Doodly
# 779
# 780
#
#                                                    標註               打卡地點  留言數  \
# 0          aiplitsao\nhaley_duu\nyany0801\nsee_u_hong                      23
# 1                                           2d.cafetw                      28
# 2                              caco_tw\nbeast_kingdom                      17
# 3                                palclair.tw\nbeltatw                      18
# 4                                        paclicensing                      13
# 5                                         PChome24h購物                      40
# 6                                                                          14
# 7                                                                          29
# 8                                                                   埔心牧場   20
# 9                                       rhinoshieldtw                      19
# 10                                                                Cafein   18
# 11                                     everymorningic                      17
# 12                                    heysong_fin2002                      17
# 13   hsiang_617\nzkl__202\nhank__0709\nyachiyo_circle            東方八千代診所   16
# 14                 vxctw.co\ncarharttwip_tw\nvxctw.co                      27
# 15                                                                        205
# 16                                      attraction.dr     ATTRACTION DR.   36
# 17                                                                  清水断崖    7
# 18                                          _ireneyu_               清水斷崖   17
# 19                    moana_inthewood\nyachiyo_circle       八千代醫美集團/千代圈圈   17
# 20                                                                         24
# 21                          nicohair_nico\nmulta_hair         MULTA hair   55
# 22                  sansan_333333\nbeautylife_4666619                      23
# 23                                       good__market                     193
# 24                                                     小亀有／ kaki gori 店。   26
# 25                                      rhinoshieldtw            花蓮貨櫃星巴克   40
# 26                             fitness_factory_taiwan           健身工廠 石牌廠   22
# 27                                         hsu_hailey                      18
# 28                                       crystery1314                      35
# 29                                 beautylife_4666619                      31
# ..                                                ...                ...  ...
# 751                                                                 OMNI    4
# 752                                                         Star Kitchen    0
# 753                                                                         1
# 754                                                                         0
# 755                                        miffy_0925               誠品綠蓋    0
# 756                                        miffy_0925                       0
# 757                                                                         1
# 758                                                                         0
# 759                                                                         1
# 760                                                                         6
# 761                                                                         0
# 762                                         _ireneyu_                       3
# 763                                                                         0
# 764                                                                         5
# 765                                                                         3
# 766                                                                         7
# 767                                                                         3
# 768                                                                         0
# 769                                                                         2
# 770                              iremcheng\nswaswahsu                       0
# 771                                                                         1
# 772                                                                         2
# 773                                                                         0
# 774                                                                         0
# 775                                                                         2
# 776                                                                         2
# 777                                                                         3
# 778                                                                         0
# 779                                                                         0
# 780                                                                         0
#
#       愛心數  標籤數  標註數  圖片數                                      貼文網址  \
# 0    2024    2    4    3  https://www.instagram.com/p/CEzHJTXH6YR/
# 1    2480    6    1    1  https://www.instagram.com/p/CEtof3UH_xx/
# 2    1853    4    2    4  https://www.instagram.com/p/CEmcaASHCTJ/
# 3    1654    4    2    4  https://www.instagram.com/p/CEjexIaHqtj/
# 4    1285   12    1    3  https://www.instagram.com/p/CEhQKL7nGD7/
# 5    1270    9    1    4  https://www.instagram.com/p/CEd_30MHczw/
# 6    1329    4    0    2  https://www.instagram.com/p/CEb8F1gn8t3/
# 7    1062   13    0    7  https://www.instagram.com/p/CEYYPacHCEt/
# 8    1427    7    0    9  https://www.instagram.com/p/CETg5wlntZI/
# 9    1613    6    1    7  https://www.instagram.com/p/CEN-WzenKxF/
# 10   1236    8    0    3  https://www.instagram.com/p/CEJYwmZnved/
# 11   2081    8    1    5  https://www.instagram.com/p/CD8l99SnsjB/
# 12   1805    1    1    7  https://www.instagram.com/p/CDjCfn5HmQm/
# 13   1612    7    4    3  https://www.instagram.com/p/CDYf3mRH04e/
# 14   1867    0    3    4  https://www.instagram.com/p/CDOMuwun8jD/
# 15   1412    0    0    4  https://www.instagram.com/p/CDBjOUhHs0h/
# 16   1744    5    1    3  https://www.instagram.com/p/CC8Zu0Tnfwg/
# 17   1342    4    0    3  https://www.instagram.com/p/CC3NGilnnAQ/
# 18   2343    6    1    5  https://www.instagram.com/p/CC0xQDUn5di/
# 19   2767    8    2    4  https://www.instagram.com/p/CCykZUVnqsc/
# 20   1853    6    0    4  https://www.instagram.com/p/CCv17ulnP-n/
# 21   4041    0    2    4  https://www.instagram.com/p/CCvjjMSHhsU/
# 22   2189    3    2    1  https://www.instagram.com/p/CCs2tYlnDL-/
# 23   1918    2    1    5  https://www.instagram.com/p/CCqrZj6Hs4x/
# 24   1594    7    0    5  https://www.instagram.com/p/CCnxsGtHUVK/
# 25   2330    8    1    3  https://www.instagram.com/p/CClCpgGnF0K/
# 26   2020    4    1    5  https://www.instagram.com/p/CCi7kU7nCfz/
# 27   1543    8    1    1  https://www.instagram.com/p/CCdggH0nHt0/
# 28   1821    0    1    4  https://www.instagram.com/p/CCVTGoPH90V/
# 29   4270    1    1    1  https://www.instagram.com/p/CCGQeoSHKgF/
# ..    ...  ...  ...  ...                                       ...
# 751    69    9    0    1   https://www.instagram.com/p/8KJXkZhCoS/
# 752    32    0    0    1   https://www.instagram.com/p/7vMV4DBCl3/
# 753    48    5    0    1   https://www.instagram.com/p/7DM1d9hCtB/
# 754    28    4    0    1   https://www.instagram.com/p/6cxUcTBCoA/
# 755    26    2    1    1   https://www.instagram.com/p/6aBLTuBCs_/
# 756    21    7    1    1   https://www.instagram.com/p/6ZcbnHhCjU/
# 757    38   10    0    1   https://www.instagram.com/p/6Pzpn9hCqo/
# 758    32    5    0    1   https://www.instagram.com/p/6CsLsbhCvK/
# 759    28    3    0    1   https://www.instagram.com/p/6AMjE2BCkG/
# 760    28    5    0    1   https://www.instagram.com/p/5y83J3BChJ/
# 761    24    4    0    1   https://www.instagram.com/p/5t-wGRhCno/
# 762    13    4    1    1   https://www.instagram.com/p/5ZEW9kBClW/
# 763    26    2    0    1   https://www.instagram.com/p/5OJGA5hCoY/
# 764    18    3    0    1   https://www.instagram.com/p/5M4T_0BCmN/
# 765    23    3    0    1   https://www.instagram.com/p/5KIdYGBCqo/
# 766    23    3    0    1   https://www.instagram.com/p/5JTSP7BCqN/
# 767    41    4    0    1   https://www.instagram.com/p/5CnDT7hCor/
# 768    18    5    0    1   https://www.instagram.com/p/4570V_BCjY/
# 769    38    4    0    1   https://www.instagram.com/p/44RC96BCmz/
# 770    25    6    2    1   https://www.instagram.com/p/4zG4C_BCp1/
