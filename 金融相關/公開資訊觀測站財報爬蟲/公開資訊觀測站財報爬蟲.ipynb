# %% [markdown]
# # 載入所需套件

# %%
import requests
import pandas as pd
import os
import time

# %% [markdown]
# # 定義爬取個股財報資料函數

# %%
def financial_statement(stock_id,year,season,statement='綜合損益彙總表'):   
    #若輸入西元年調整成民國年
    if year>=1911:
        year-=1911
   
    form_data={'encodeURIComponent':1,
               'step':1,
               'firstin':1,
               'off':1,
               'co_id':stock_id,
               'year':year,
               'season':season}
    
    if statement=='資產負債彙總表':
        url='https://mops.twse.com.tw/mops/web/ajax_t164sb03'
        #餵入form_data
        response=requests.post(url,form_data)
        df=pd.read_html(response.text)[1].fillna('')
        df=df.iloc[:,:-2]
    elif statement=='綜合損益彙總表':
        url='https://mops.twse.com.tw/mops/web/ajax_t164sb04'
        #餵入form_data
        response=requests.post(url,form_data)
        df=pd.read_html(response.text)[1].fillna('')
        df=df.iloc[:,:-1]
    elif statement=='現金流量彙總表':
        url='https://mops.twse.com.tw/mops/web/ajax_t164sb05'
        #餵入form_data
        response=requests.post(url,form_data)
        df=pd.read_html(response.text)[1].fillna('')
        df=df.iloc[:,:-4]
    else:
        print('type does not match')
    
    return df

# %% [markdown]
# # 爬取指定年份個股財報資料

# %%
financial_statement(2330,107,4,'資產負債彙總表')
# Out:
#                       民國107年第4季
#                        單位：新台幣仟元
#                            會計項目   107年12月31日          106年12月31日
#              Unnamed: 0_level_3           金額      %           金額      %
# 0                          流動資產
# 1                       現金及約當現金  5.77815e+08  27.64  5.53392e+08  27.78
# 2           透過損益按公允價值衡量之金融資產－流動  3.50459e+06   0.17       569751   0.03
# 3       透過其他綜合損益按公允價值衡量之金融資產－流動  9.95617e+07   4.76            0      0
# 4                 備供出售金融資產－流動淨額            0      0  9.33742e+07   4.69
# 5               持有至到期日金融資產－流動淨額            0      0  1.98838e+06    0.1
# 6                  避險之衍生金融資產－流動            0      0        34394      0
# 7            按攤銷後成本衡量之金融資產－流動淨額  1.42776e+07   0.68            0      0
# 8                    避險之金融資產－流動        23497      0            0      0
# 9                        應收帳款淨額  1.28613e+08   6.15  1.21133e+08   6.08
# 10                   應收帳款－關係人淨額       584412   0.03  1.18412e+06   0.06
# 11                  其他應收款－關係人淨額        65028      0       171058   0.01
# 12                           存貨  1.03231e+08   4.94  7.38807e+07   3.71
# 13                       其他流動資產  2.40039e+07   1.15  1.14756e+07   0.58
# 14                       流動資產合計   9.5168e+08  45.53  8.57203e+08  43.04
# 15                        非流動資產
# 16     透過其他綜合損益按公允價值衡量之金融資產－非流動  3.91068e+06   0.19            0      0
# 17             持有至到期日金融資產－非流動淨額            0      0  1.88333e+07   0.95
# 18          按攤銷後成本衡量之金融資產－非流動淨額  7.52828e+06   0.36            0      0
# 19             以成本衡量之金融資產－非流動淨額            0      0  4.87426e+06   0.24
# 20                   採用權益法之投資淨額  1.78658e+07   0.85  1.78615e+07    0.9
# 21                    不動產、廠房及設備  1.07205e+09  51.29  1.06254e+09  53.34
# 22                         無形資產  1.70021e+07   0.81  1.41751e+07   0.71
# 23                      遞延所得稅資產  1.68064e+07    0.8  1.21055e+07   0.61
# 24                      其他非流動資產  3.28472e+06   0.16  4.26653e+06   0.21
# 25                      非流動資產合計  1.13845e+09  54.47  1.13466e+09  56.96
# 26                         資產總額  2.09013e+09    100  1.99186e+09    100
# 27                         流動負債
# 28                         短期借款  8.87546e+07   4.25  6.37668e+07    3.2
# 29          透過損益按公允價值衡量之金融負債－流動        40825      0        26709      0
# ..                          ...          ...    ...          ...    ...
# 39                        非流動負債
# 40                        應付公司債     5.69e+07   2.72     9.18e+07   4.61
# 41                      遞延所得稅負債       233284   0.01       302205   0.02
# 42                      其他非流動負債  1.49558e+07   0.72  1.82931e+07   0.92
# 43                      非流動負債合計  7.20891e+07   3.45  1.10395e+08   5.54
# 44                         負債總額  4.12632e+08  19.74  4.69102e+08  23.55
# 45                  歸屬於母公司業主之權益
# 46                           股本
# 47                        普通股股本  2.59304e+08  12.41  2.59304e+08  13.02
# 48                         股本合計  2.59304e+08  12.41  2.59304e+08  13.02
# 49                         資本公積
# 50                    資本公積－發行溢價  3.30778e+07   1.58  3.30778e+07   1.66
# 51          資本公積-認列對子公司所有權權益變動數       121473   0.01       118792   0.01
# 52                    資本公積－受贈資產        29343      0        19208      0
# 53  資本公積－採用權益法認列關聯企業及合資股權淨值之變動數       282820   0.01       289240   0.01
# 54                    資本公積－合併溢額  2.28045e+07   1.09  2.28045e+07   1.14
# 55                       資本公積合計  5.63159e+07   2.69  5.63095e+07   2.83
# 56                         保留盈餘
# 57                       法定盈餘公積  2.76034e+08  13.21  2.41723e+08  12.14
# 58                       特別盈餘公積  2.69075e+07   1.29            0      0
# 59                未分配盈餘（或待彌補虧損）  1.07371e+09  51.37  9.91639e+08  49.78
# 60                       保留盈餘合計  1.37665e+09  65.86  1.23336e+09  61.92
# 61                         其他權益
# 62                       其他權益合計 -1.54499e+07  -0.74 -2.69178e+07  -1.35
# 63                歸屬於母公司業主之權益合計  1.67682e+09  80.23  1.52206e+09  76.41
# 64                        非控制權益       678731   0.03       702110   0.04
# 65                         權益總額   1.6775e+09  80.26  1.52276e+09  76.45
# 66                      負債及權益總計  2.09013e+09    100  1.99186e+09    100
# 67      預收股款（權益項下）之約當發行股數（單位：股）            0                   0
# 68    母公司暨子公司所持有之母公司庫藏股股數（單位：股）            0                   0
#
# [69 rows x 5 columns]

# %% [markdown]
# # 爬取指定時間範圍個股各項財報資料

# %%
stock_ids=[2303,2330]
years=range(106,108)
seasons=range(1,5)
statements=['資產負債彙總表','綜合損益彙總表','現金流量彙總表']

for stock_id in stock_ids:
    print('{}:'.format(stock_id))
    for year in years:
        print('{}年'.format(year))
        for season in seasons:
            print('第{}季'.format(season))
            directory='每季個股財務報表資料/{}/{}年/第{}季'.format(stock_id,year,season)
            if not os.path.isdir(directory):
                os.makedirs(directory)
            for statement in statements:            
                if not os.path.exists(directory+'/{}.xlsx'.format(statement)):
                    df=financial_statement(stock_id,year,season,statement)
                    df.to_excel(directory+'/{}.xlsx'.format(statement))
                    time.sleep(3)
# Out:
# 2303:
# 106年
# 第1季
# 第2季
# 第3季
# 第4季
# 107年
# 第1季
# 第2季
# 第3季
# 第4季
# 2330:
# 106年
# 第1季
# 第2季
# 第3季
# 第4季
# 107年
# 第1季
# 第2季
# 第3季
# 第4季
