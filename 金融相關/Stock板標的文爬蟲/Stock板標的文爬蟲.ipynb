# %% [markdown]
# # 載入所需套件

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from concurrent import futures
from tqdm import tqdm

pd.set_option('mode.chained_assignment',None)

# %% [markdown]
# # 定義進入每篇標的文章爬取分析資訊函數

# %%
def details_crawler(link_list):
    link=link_list[0]
    i=link_list[1]
    r=requests.get(link)
    s=BeautifulSoup(r.text,'html.parser')
    #處理可能抓不到時間的問題
    try:
        tim=s.select('div.article-metaline')[2].text[2:]
    except:
        tim=np.nan
    
    content=s.select('#main-content')[0].text.replace(' :','：').replace(':','：').replace('---','').replace('多/空/請益/心得','').replace('(非長期投資者，必須有停損機制)','')
    
    #處理可能文章格式錯誤問題
    if '1. 標的：' in content:                  
        idx_1=content.index('1. 標的：')
        idx_2=content.index('2. 分類：')
        idx_3=content.index('3. 分析/正文：')
        idx_5=content.index('--')
        
        stock=content[idx_1:idx_2].replace('\n','').split('標的：')[1].replace(' ','')
        direction=content[idx_2:idx_3].replace('\n','').split('分類：')[1].replace(':','').replace(' ','')
        
        #處理可能文章最後項目不存在格式錯誤問題
        if '4. 進退場機制：' in content:
            idx_4=content.index('4. 進退場機制：')
            analysis=content[idx_3:idx_4].replace('\n','').split('正文：')[1].replace(' ','')
            stop=content[idx_4:idx_5].replace('\n','').split('進退場機制：')[1].replace(' ','')
        else:
            #若文章格式不對將剩下所有內容指派到分析欄位
            analysis=content[idx_3:idx_5].replace('\n','').split('正文：')[1].replace(' ','')
            stop=np.nan
             
    else:
        idx_1=content.index('\n\n')
        idx_2=content.index('--')
        
        stock=np.nan
        direction=np.nan
        #若文章格式不對將所有內容指派到分析欄位
        analysis=content[idx_1:idx_2].replace('\n','').replace(' ','')
        stop=np.nan
    
    return i,tim,stock,direction,analysis,stop

# %% [markdown]
# # 定義爬取單頁Stock板標的文章資訊函數

# %%
def ptt_stock_crawler(url):   
    response=requests.get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    entrys=soup.select('div.r-ent')
    
    titles,dates,authors,recommends,links=[],[],[],[],[]

    for entry in entrys:
        try:
            titles.append(entry.select('div.title a')[0].text)
        except:
            titles.append(np.nan)
        try:
            links.append('https://www.ptt.cc{}'.format(entry.select('div.title a')[0]['href']))
        except:
            links.append(np.nan)
        
        dates.append(entry.select('div.date')[0].text)
        if entry.select('div.author')[0].text=='-':
            authors.append(np.nan)
        else:
            authors.append(entry.select('div.author')[0].text)  
        
        if entry.select('div.nrec')[0].text=='':
            recommends.append(np.nan)
        else:
            recommends.append(entry.select('div.nrec')[0].text) 
    
    df=pd.DataFrame({
        '標題':titles,
        '日期':dates,
        '作者':authors,
        '推數':recommends,
        '網址':links
    })
    df.dropna(axis=0,inplace=True)
    df['推數'].replace('爆','99',inplace=True)
    df=df[~df['推數'].str.startswith('X')]
    df_s=df[(df['標題'].str.contains('標的'))&(~df['標題'].str.contains('Re:'))&(~df['標題'].str.contains('R:'))]
    df_s.reset_index(drop=True,inplace=True)
    
    #處理標的文特殊欄位
    link_list=[]
    for i in range(len(df_s['網址'])):
        link_list.append([df_s['網址'][i],i])
    
    times=[0]*len(df_s['網址'])
    stocks=[0]*len(df_s['網址'])
    directions=[0]*len(df_s['網址'])
    analyses=[0]*len(df_s['網址'])
    stops=[0]*len(df_s['網址'])
    
    
    #進入每個連結爬取(執行thread層級的非同步任務)
    with futures.ThreadPoolExecutor(max_workers=8) as executor:
        results=list(executor.map(details_crawler,link_list))
        
        for future in results:
            i,tim,stock,direction,analysis,stop=future
            times[i]=tim
            stocks[i]=stock
            directions[i]=direction
            analyses[i]=analysis
            stops[i]=stop
    
    df_s.loc[:,'時間']=times
    df_s.loc[:,'標的']=stocks
    df_s.loc[:,'方向']=directions
    df_s.loc[:,'分析']=analyses
    df_s.loc[:,'進退場']=stops
    
    return df,df_s

# %% [markdown]
# # 定義爬取多頁Stock板標的文章資訊函數

# %%
def page_function(page):    
    url='https://www.ptt.cc/bbs/Stock/index.html'
    dfs,dfs_s=[],[]
    df,df_s=ptt_stock_crawler(url)
    dfs.append(df)
    dfs_s.append(df_s)
    
    for i in tqdm(range(page)):
        response=requests.get(url)
        soup=BeautifulSoup(response.text,'html.parser')
        paging=soup.select('div.btn-group-paging a')
        url='https://www.ptt.cc{}'.format(paging[1]['href'])
        df,df_s=ptt_stock_crawler(url)
        dfs.append(df)
        dfs_s.append(df_s)
    
    df=pd.concat(dfs,ignore_index=True)
    df_s=pd.concat(dfs_s,ignore_index=True) 
    
    return df,df_s

# %% [markdown]
# # 抓取Stock板標的文章資訊

# %%
df,df_s=page_function(20)
df.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:23<00:00,  1.15s/it]
#                           標題     日期            作者  推數  \
# 0        Re: [心得] 最後的 1500 點   2/09    kusomanfcu   3
# 1        Re: [心得] 最後的 1500 點   2/09    HolyMickey  12
# 2      [新聞] 從數字看懂台灣口罩之亂的真相     2/09    zakijudelo  21
# 3        Re: [心得] 最後的 1500 點   2/09  spiritempire  11
# 4  Re: [新聞] 從數字看懂台灣口罩之亂的真相     2/09    kusomanfcu  11
#
#                                                   網址
# 0  https://www.ptt.cc/bbs/Stock/M.1581228580.A.E2...
# 1  https://www.ptt.cc/bbs/Stock/M.1581232958.A.E0...
# 2  https://www.ptt.cc/bbs/Stock/M.1581233543.A.F5...
# 3  https://www.ptt.cc/bbs/Stock/M.1581235706.A.65...
# 4  https://www.ptt.cc/bbs/Stock/M.1581235724.A.4E...

# %%
df_s.head()
# Out:
#               標題     日期           作者  推數  \
# 0    [標的] 旺宏2337   2/09    cchaha123  24
# 1  [標的] A50指 回檔多   2/09      illdoit   5
# 2  [標的] 2618 長榮航   2/08      kgb2938  36
# 3   [標的] 6202 盛群   2/08  fashionbaby  13
# 4  [標的] 6488 環球晶   2/08      wii0620  33
#
#                                                   網址  \
# 0  https://www.ptt.cc/bbs/Stock/M.1581246654.A.0B...
# 1  https://www.ptt.cc/bbs/Stock/M.1581222717.A.F3...
# 2  https://www.ptt.cc/bbs/Stock/M.1581167199.A.1F...
# 3  https://www.ptt.cc/bbs/Stock/M.1581175815.A.16...
# 4  https://www.ptt.cc/bbs/Stock/M.1581100309.A.E9...
#
#                          時間       標的  方向  \
# 0  Sun Feb  9 19:10:52 2020   旺宏2337  請益
# 1  Sun Feb  9 12:31:52 2020     A50指   多
# 2  Sat Feb  8 21:06:37 2020      長榮航  請益
# 3  Sat Feb  8 23:30:12 2020   6202盛群   多
# 4  Sat Feb  8 02:31:40 2020  6488環球晶  請益
#
#                                                   分析  \
# 0  各位先進大家好,小妹初入股市三個月,第一筆便當錢就是靠旺宏賺來的,現在對這隻股票不知該進還是...
# 1  病毒面：RNA病毒，構造簡單，容易變異空氣傳播，黏膜接觸傳染。4度左右溫度可以穩定存在-60...
# 2  最近航空股的討論熱度有明顯增溫的趨勢，原因不外乎就是因為疫情的關係，對首當其衝的航空股來說是...
# 3     防疫概念股，且第四季單季獲利不錯，而且在武漢疫情下，耳溫槍晶片供不應求，預估長波段走勢續看多
# 4  大家好，小弟是股市擦鞋童剛入市沒多久幻想抱股過好年結果遇到武漢起疫直接套在起跌點，砍在阿呆谷...
#
#                                                  進退場
# 0                                                NaN
# 1  13000↓買入或者4HK基準轉換黃金交叉破了還有月30ma撐著再破還有上次破月30ma支撐...
# 2                                                NaN
# 3                                          進場71,停利85
# 4  　下周一開盤找機會進場　突破前高441.5停損請教各位大大這樣進場會被嘎到外太空嗎==賺再多...

# %% [markdown]
# # 將Stock板標的文章資訊匯出成Excel檔

# %%
df_s.to_excel('Stock板標的文.xlsx',index=False)
